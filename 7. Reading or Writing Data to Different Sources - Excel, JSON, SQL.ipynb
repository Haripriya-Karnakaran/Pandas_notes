# %%
import pandas as pd

# %%
df = pd.read_csv("Dataset/survey_results_public.csv")

# %%
pd.set_option("display.max_columns",84)
pd.set_option("display.max_rows",84)

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
filt = (df["Country"] == "India")
india_df = df.loc[filt]            # here we making india as a separate df

# %%
india_df
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 9              10  I agree                     I am a developer by profession
# 66             67  I agree                     I am a developer by profession
# 78             79  I agree                     I am a developer by profession
# 82             83  I agree                     I am a developer by profession
# 85             86  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89119       89120  I agree                     I am a developer by profession
# 89121       89122  I agree  I am not primarily a developer, but I write co...
# 89164       89165  I agree                     I am a developer by profession
# 89165       89166  I agree                     I am a developer by profession
# 89167       89168  I agree                     I am a developer by profession
#
# ...

# %%
# to convert this india df to a csv file

india_df.to_csv("Dataset/India_csv.csv") # now we can see this csv in dataset folder

# %%
# tsv file - Tab-separated values (TSV) is a simple, text-based file format for storing tabular data. 
# Records are separated by newlines, and values within a record are separated by tab characters. 
# The TSV format is thus a delimiter-separated values format, similar to comma-separated values

# In simple, tsv files are like converting a tsv from csv by using using tab as a delimiter instead of comma, which is used for making table easily

# %%
# tsv

india_df.to_csv("Dataset/India_tsv.tsv",sep = "\t") # here we are spearating each data with tabs

# %%
# for excel file

# to create a excel, first we need to install some  packagaes using jupyter terminal or a normal terminal
# for installation, type - pip install xlwt openpyxl xlrd
# here xlwt is for writing something on excel file, openpyxl is for opening excel, xlrd - to read the excel.these 3 are packages

india_df.to_excel("Dataset/India_excel.xlsx")

# %%
# to read the excel file

test = pd.read_excel("Dataset/India_excel.xlsx",index_col = "ResponseId")

# %%
test
# Out:
#             Unnamed: 0     Q120  \
# ResponseId
# 10                   9  I agree
# 67                  66  I agree
# 79                  78  I agree
# 83                  82  I agree
# 86                  85  I agree
# ...                ...      ...
# 89120            89119  I agree
# 89122            89121  I agree
# 89165            89164  I agree
# 89166            89165  I agree
# 89168            89167  I agree
#
#                                                    MainBranch  \
# ResponseId
# 10                             I am a developer by profession
# 67                             I am a developer by profession
# 79                             I am a developer by profession
# 83                             I am a developer by profession
# 86                             I am a developer by profession
# ...                                                       ...
# 89120                          I am a developer by profession
# ...

# %%
# for json

india_df.to_json("Dataset/India_json.json") # when we open that file, it will be in the form of dictionary 
# we can see a dictionary, iwthin that we will hava another dict which contains all the respected values

# %%
india_df.to_json("Dataset/India_json.json",orient = "records",lines = True) # now open that file by reloading it again

# %%
# to read json

test1 = pd.read_json("Dataset/India_json.json",orient = "records",lines = True)

# %%
test1
# Out:
#       ResponseId     Q120                                         MainBranch  \
# 0             10  I agree                     I am a developer by profession
# 1             67  I agree                     I am a developer by profession
# 2             79  I agree                     I am a developer by profession
# 3             83  I agree                     I am a developer by profession
# 4             86  I agree                     I am a developer by profession
# ...          ...      ...                                                ...
# 5620       89120  I agree                     I am a developer by profession
# 5621       89122  I agree  I am not primarily a developer, but I write co...
# 5622       89165  I agree                     I am a developer by profession
# 5623       89166  I agree                     I am a developer by profession
# 5624       89168  I agree                     I am a developer by profession
#
# ...

# %%
# now, to connect with sql, we need to install a package which is SQLAlchemy...for that, go to terminal and type,
# pip install SQLAlchemy
# also install, pip install mysqlclient
# again to connect our mysql with jupyter notebook, type this command, pip install mysql-connector-python

# this will vary for each database like mysql,postgresql

# %%
from sqlalchemy import create_engine  # engine to connect with database
import mysql

# %%
engine = create_engine("mysql://root:3902@localhost/customer") # username-root and pass,database name

# %%
# We are going to import our df as a table to sql database
# if_exists - "replace" is for if the table which we creating is already existed in the database means,it will replace it into new one
india_df.to_sql("sample_table", engine, schema=None, if_exists='replace', index=False)  # sample table is a name we want to be our df
# Out:
# 5625

# %%
import pandas as pd
import sqlalchemy as sa
import pymysql  # or import MySQLdb

print(pd.__version__)
print(sa.__version__)
print(pymysql.__version__)  # or print(MySQLdb.__version__)
# Out:
# 2.2.2
# 2.0.30
# 1.4.6

# %%
import sys

# %%
sys.version
# Out:
# '3.9.19 (main, Mar 21 2024, 17:21:27) [MSC v.1916 64 bit (AMD64)]'

# %%
# engine = create_engine("mysql+pymysql://root:3902@localhost/customer")

# %%
# next we can go and see the data in our sql workbench

# %%
# to read data from sql file

sql_df = pd.read_sql("sample_table",engine,index_col = "ResponseId")

# %%
sql_df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 10          I agree  I am a developer by profession  25-34 years old
# 67          I agree  I am a developer by profession  25-34 years old
# 79          I agree  I am a developer by profession  18-24 years old
# 83          I agree  I am a developer by profession  25-34 years old
# 86          I agree  I am a developer by profession  25-34 years old
#
#                                     Employment  \
# ResponseId
# 10          Not employed, but looking for work
# 67                         Employed, full-time
# 79                         Employed, full-time
# 83                         Employed, full-time
# 86                         Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 10                                          None
# 67          Hybrid (some remote, some in-person)
# 79                                        Remote
# ...

# %%
# to perform an sql query

sql_df = pd.read_sql_query("SELECT * FROM sample_table WHERE ResponseId >= 80",engine,index_col = "ResponseId")

# %%
sql_df  # now it starts from 83
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 83          I agree                     I am a developer by profession
# 86          I agree                     I am a developer by profession
# 106         I agree                              I am learning to code
# 128         I agree                     I am a developer by profession
# 136         I agree                     I am a developer by profession
# ...             ...                                                ...
# 89120       I agree                     I am a developer by profession
# 89122       I agree  I am not primarily a developer, but I write co...
# 89165       I agree                     I am a developer by profession
# 89166       I agree                     I am a developer by profession
# 89168       I agree                     I am a developer by profession
#
#                         Age  \
# ResponseId
# 83          25-34 years old
# 86          25-34 years old
# ...

# %%
# we can use an external json file to pandas here

# test_df = pd.read_json("https://github.com/lorenwest/lorenwest.github.com/blob/master/node-config/0.4.24/index.json")
