# %%
import pandas as pd

# %%
df1 = pd.read_csv("Dataset/survey_results_public.csv")
schema_df = pd.read_csv("Dataset/survey_results_schema.csv")

# %%
pd.set_option("display.max_rows()",84)
pd.set_option("display.max_columns()",84)

# %%
df1
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df1.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
schema_df.head()
# Out:
#       qid     qname                                           question  \
# 0   QID16        S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12  MetaInfo                                  Browser Meta Info
# 2  QID310      Q310  <div><span style="font-size:19px;"><strong>You...
# 3  QID312      Q120
# 4    QID1        S1  <span style="font-size:22px; font-family: aria...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    DB       TB

# %%
# to find the median for a column

df1["ConvertedCompYearly"].head(15)
# Out:
# 0          NaN
# 1     285000.0
# 2     250000.0
# 3     156000.0
# 4      23456.0
# 5      96828.0
# 6     135000.0
# 7      80000.0
# 8      64254.0
# 9          NaN
# 10         NaN
# 11     78003.0
# 12     75000.0
# 13    150000.0
# 14    187407.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df1["ConvertedCompYearly"].median()  # median is a typical value like a center value for a data
# Out:
# 74963.0

# %%
df1.median()
# Out:
# C:\Users\Haripriya\AppData\Local\Temp\ipykernel_16092\865143426.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.median()
# ResponseId              44592.5
# CompTotal              115000.0
# WorkExp                     9.0
# ConvertedCompYearly     74963.0
# dtype: float64

# %%
df1.describe()  # describe() is a convinient way to get a quick overview of a data
# Out:
#          ResponseId     CompTotal       WorkExp  ConvertedCompYearly
# count  89184.000000  4.822500e+04  43579.000000         4.801900e+04
# mean   44592.500000  1.036807e+42     11.405126         1.031101e+05
# std    25745.347541  2.276847e+44      9.051989         6.814188e+05
# min        1.000000  0.000000e+00      0.000000         1.000000e+00
# 25%    22296.750000  6.300000e+04      5.000000         4.390700e+04
# 50%    44592.500000  1.150000e+05      9.000000         7.496300e+04
# 75%    66888.250000  2.300000e+05     16.000000         1.216410e+05
# max    89184.000000  5.000000e+46     50.000000         7.435143e+07

# %%
# count() - helps to find how many data are there in that column
df1["ConvertedCompYearly"].count()  # here, in convertedcompyearly...only 48019 has a data rest doesnt have any value(missing value)
# Out:
# 48019

# %%
df1.count()  # for all data
# Out:
# ResponseId                             89184
# Q120                                   89184
# MainBranch                             89184
# Age                                    89184
# Employment                             87898
# RemoteWork                             73810
# CodingActivities                       73764
# EdLevel                                87973
# LearnCode                              87663
# LearnCodeOnline                        70084
# LearnCodeCoursesCert                   37076
# YearsCode                              87435
# YearsCodePro                           66136
# DevType                                76872
# OrgSize                                65043
# PurchaseInfluence                      64964
# TechList                               60851
# BuyNewTool                             83009
# Country                                87973
# Currency                               65334
# CompTotal                              48225
# ...

# %%
# to find the count of individual data in a column

schema_df["force_resp"].value_counts()  # in this particular column, there are 58 false and 9 true
# Out:
# False    58
# True      9
# Name: force_resp, dtype: int64

# %%
schema_df["force_resp"].value_counts(normalize = True) # normalize - returns the relative frequency or proportion of unique value from the whole data
# Out:
# False    0.865672
# True     0.134328
# Name: force_resp, dtype: float64

# %% [markdown]
# ### grouping
# ```python
#              Grouping in pandas involves splitting the data into groups based on some criteria,
#              applying a function to each group independently, and then combining the results.
#              This is particularly useful for performing operations on subsets of data and aggregating results.
# ```

# %%
df1["Country"].value_counts()
# Out:
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: Country, Length: 185, dtype: int64

# %%
country_grp = df1.groupby(["Country"])

# %%
country_grp.get_group("United States of America") # here only the data which are united states has been generated
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 1               2  I agree                     I am a developer by profession
# 2               3  I agree                     I am a developer by profession
# 3               4  I agree                     I am a developer by profession
# 6               7  I agree                     I am a developer by profession
# 7               8  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89150       89151  I agree  I used to be a developer by profession, but no...
# 89154       89155  I agree                     I am a developer by profession
# 89156       89157  I agree                     I am a developer by profession
# 89175       89176  I agree                     I am a developer by profession
# 89178       89179  I agree                     I am a developer by profession
#
# ...

# %%
country_grp.get_group("India")  # only india
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 9              10  I agree                     I am a developer by profession
# 66             67  I agree                     I am a developer by profession
# 78             79  I agree                     I am a developer by profession
# 82             83  I agree                     I am a developer by profession
# 85             86  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89119       89120  I agree                     I am a developer by profession
# 89121       89122  I agree  I am not primarily a developer, but I write co...
# 89164       89165  I agree                     I am a developer by profession
# 89165       89166  I agree                     I am a developer by profession
# 89167       89168  I agree                     I am a developer by profession
#
# ...

# %%
# we can get the same using filter

filt = df1["Country"] == "India"     # only india is here
df1.loc[filt]
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 9              10  I agree                     I am a developer by profession
# 66             67  I agree                     I am a developer by profession
# 78             79  I agree                     I am a developer by profession
# 82             83  I agree                     I am a developer by profession
# 85             86  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89119       89120  I agree                     I am a developer by profession
# 89121       89122  I agree  I am not primarily a developer, but I write co...
# 89164       89165  I agree                     I am a developer by profession
# 89165       89166  I agree                     I am a developer by profession
# 89167       89168  I agree                     I am a developer by profession
#
# ...

# %%
# to group something by another column
country_grp["RemoteWork"].value_counts()
# Out:
# Country      RemoteWork
# Afghanistan  Hybrid (some remote, some in-person)    17
#              Remote                                  17
#              In-person                                8
# Albania      Hybrid (some remote, some in-person)    18
#              In-person                               17
#                                                      ..
# Zambia       Hybrid (some remote, some in-person)     5
#              Remote                                   3
# Zimbabwe     Remote                                   7
#              Hybrid (some remote, some in-person)     5
#              In-person                                5
# Name: RemoteWork, Length: 490, dtype: int64

# %%
country_grp["RemoteWork"].value_counts().head(50)
# Out:
# Country              RemoteWork
# Afghanistan          Hybrid (some remote, some in-person)     17
#                      Remote                                   17
#                      In-person                                 8
# Albania              Hybrid (some remote, some in-person)     18
#                      In-person                                17
#                      Remote                                   15
# Algeria              Remote                                   27
#                      Hybrid (some remote, some in-person)     12
#                      In-person                                11
# Andorra              In-person                                 6
#                      Remote                                    5
#                      Hybrid (some remote, some in-person)      2
# Angola               Hybrid (some remote, some in-person)      3
#                      In-person                                 3
# ...

# %%
# to see only for specific object eg: only for india

country_grp["RemoteWork"].value_counts().loc["India"]
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    1638
# Remote                                  1405
# In-person                               1104
# Name: RemoteWork, dtype: int64

# %%
country_grp["RemoteWork"].value_counts(normalize = True).loc["India"]
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    0.394984
# Remote                                  0.338799
# In-person                               0.266217
# Name: RemoteWork, dtype: float64

# %%
country_grp["ConvertedCompYearly"].median() # can get the median for each country
# Out:
# Country
# Afghanistan                               915.0
# Albania                                 10741.0
# Algeria                                  8782.0
# Andorra                                 42836.0
# Angola                                   4302.0
#                                          ...
# Venezuela, Bolivarian Republic of...    12000.0
# Viet Nam                                12763.0
# Yemen                                    6500.0
# Zambia                                   9687.0
# Zimbabwe                                12500.0
# Name: ConvertedCompYearly, Length: 185, dtype: float64

# %%
country_grp["ConvertedCompYearly"].median().loc["Germany"] # to get the median for specific country we use loc
# Out:
# 74963.0

# %%
# to get the median,mean 

country_grp["ConvertedCompYearly"].agg(["median","mean"])
# Out:
#                                        median           mean
# Country
# Afghanistan                             915.0  843636.090909
# Albania                               10741.0   29219.450000
# Algeria                                8782.0   10069.190476
# Andorra                               42836.0  120368.800000
# Angola                                 4302.0    4302.000000
# ...                                       ...            ...
# Venezuela, Bolivarian Republic of...  12000.0   23068.851852
# Viet Nam                              12763.0   20995.956140
# Yemen                                  6500.0   15089.333333
# Zambia                                 9687.0   13897.800000
# Zimbabwe                              12500.0   26740.000000
#
# [185 rows x 2 columns]

# %%
# to get mean,median aggregations for specific country
country_grp["ConvertedCompYearly"].agg(["median","mean"]).loc["Germany"]
# Out:
# median    74963.000000
# mean      82457.479093
# Name: Germany, dtype: float64

# %%
# to see how many have worked with python

filt = df1["Country"] == "India"
df1.loc[filt]["LanguageHaveWorkedWith"].str.contains("Python")#it gives boolean values as true means know python else false
# Out:
# 9         True
# 66       False
# 78       False
# 82       False
# 85       False
#          ...
# 89119     True
# 89121     True
# 89164     True
# 89165    False
# 89167    False
# Name: LanguageHaveWorkedWith, Length: 5625, dtype: object

# %%
# sum() will work with boolean values too since true means 1 and flase means 0

filt = df1["Country"] == "India"
df1.loc[filt]["LanguageHaveWorkedWith"].str.contains("Python").sum()
# Out:
# 2793

# %%
country_grp["LanguageHaveWorkedWith"].str.contains("Python").sum() 
# this wont work if we want to know how many knows python for each country
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 country_grp["LanguageHaveWorkedWith"].str.contains("Python").sum()
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:911, in GroupBy.__getattr__(self, attr)
#     908 if attr in self.obj:
#     909     return self[attr]
# --> 911 raise AttributeError(
#     912     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
# instead we use apply()
country_grp["LanguageHaveWorkedWith"].apply(lambda x : x.str.contains("Python").sum())
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
# Practise questions

# what % of people from each country knows python?

country_respondents = df1["Country"].value_counts()
country_respondents
# Out:
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: Country, Length: 185, dtype: int64

# %%
country_uses_python = country_grp["LanguageHaveWorkedWith"].apply(lambda x : x.str.contains("Python").sum())
country_uses_python
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
python_df = pd.concat([country_respondents,country_uses_python],axis = "columns",sort = False)
python_df    # country - about 18647 people said they are from usa and languagehaveworkedwith is python 10062
# Out:
#                                                     Country  \
# United States of America                              18647
# Germany                                                7328
# India                                                  5625
# United Kingdom of Great Britain and Northern Ir...     5552
# Canada                                                 3507
# ...                                                     ...
# Saint Kitts and Nevis                                     1
# Marshall Islands                                          1
# Samoa                                                     1
# Central African Republic                                  1
# San Marino                                                1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                             10062
# Germany                                                               3686
# ...

# %%
python_df.rename(columns = {"Country":"No_of_Respondents","LanguageHaveWorkedWith":"Knows_python"},inplace = True)
python_df
# Out:
#                                                     No_of_Respondents  \
# United States of America                                        18647
# Germany                                                          7328
# India                                                            5625
# United Kingdom of Great Britain and Northern Ir...               5552
# Canada                                                           3507
# ...                                                               ...
# Saint Kitts and Nevis                                               1
# Marshall Islands                                                    1
# Samoa                                                               1
# Central African Republic                                            1
# San Marino                                                          1
#
#                                                     Knows_python
# ...

# %%
# create a new column for percentage for python people

python_df["Percent_knows_python"] = (python_df["Knows_python"] / python_df["No_of_Respondents"])*100
python_df
# Out:
#                                                     No_of_Respondents  \
# United States of America                                        18647
# Germany                                                          7328
# India                                                            5625
# United Kingdom of Great Britain and Northern Ir...               5552
# Canada                                                           3507
# ...                                                               ...
# Saint Kitts and Nevis                                               1
# Marshall Islands                                                    1
# Samoa                                                               1
# Central African Republic                                            1
# San Marino                                                          1
#
#                                                     Knows_python  \
# ...

# %%
python_df.sort_values(by = "Percent_knows_python",ascending = False,inplace = True)
python_df
# Out:
#                                        No_of_Respondents  Knows_python  \
# San Marino                                             1             1
# North Korea                                            4             4
# Samoa                                                  1             1
# Liechtenstein                                          1             1
# Grenada                                                1             1
# ...                                                  ...           ...
# Guinea                                                 2             0
# Monaco                                                 2             0
# Bahamas                                                2             0
# Gabon                                                  2             0
# Democratic People's Republic of Korea                  2             0
#
#                                        Percent_knows_python
# ...

# %%
python_df.head(50)
# Out:
#                                   No_of_Respondents  Knows_python  \
# San Marino                                        1             1
# North Korea                                       4             4
# Samoa                                             1             1
# Liechtenstein                                     1             1
# Grenada                                           1             1
# Congo, Republic of the...                         2             2
# Dominica                                          2             2
# Saint Lucia                                       2             2
# Lesotho                                           4             4
# Mali                                              6             5
# Democratic Republic of the Congo                  5             4
# Oman                                             11             8
# Liberia                                           3             2
# ...

# %%
# for specific column

python_df.loc["Japan"]
# Out:
# No_of_Respondents       362.000000
# Knows_python            188.000000
# Percent_knows_python     51.933702
# Name: Japan, dtype: float64
